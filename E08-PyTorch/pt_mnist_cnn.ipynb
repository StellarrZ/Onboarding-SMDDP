# %%
# !pip --version
# !echo "---"
# !pip show torch torchvision
# Out:
# pip 22.0.3 from /opt/conda/lib/python3.8/site-packages/pip (python 3.8)
# ---
# Name: torch
# Version: 1.10.2+cu113
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /opt/conda/lib/python3.8/site-packages
# Requires: typing-extensions
# Required-by: awsio, torchnet, torchvision
# ---
# Name: torchvision
# Version: 0.11.3
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: /opt/conda/lib/python3.8/site-packages
# Requires: numpy, pillow, torch
# Required-by:

# %%
import os
os.chdir("/root/SMDDP/Onboarding-SMDDP/E08-PyTorch/examples")
# !pwd
# !ls -lh | grep mnist
# Out:
# /root/SMDDP/Onboarding-SMDDP/E08-PyTorch/examples
# drwxr-xr-x  2 root root   62 May 12 15:49 mnist
# -rw-r--r--  1 root root 4.6M May 12 15:47 mnist_cnn.pt
# drwxr-xr-x  2 root root   61 May 12 15:03 mnist_hogwild

# %%
# !ls -lRah mnist
# Out:
# mnist:
# total 20K
# drwxr-xr-x  2 root root   62 May 12 15:49 .
# drwxr-xr-x 22 root root 4.0K May 12 15:44 ..
# -rw-r--r--  1 root root  152 May 12 15:03 README.md
# -rw-r--r--  1 root root 5.3K May 12 15:03 main.py
# -rw-r--r--  1 root root   18 May 12 15:03 requirements.txt

# %%
""" https://github.com/pytorch/examples/tree/main/mnist """
# !python mnist/main.py --epochs 10 --save-model | tee ../log.txt
# !mv ./mnist_cnn.pt ../mnist_cnn.pt
# Out:
# /opt/conda/lib/python3.8/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# [2022-05-12 15:49:55.981 8aee3ff2d8c5:70200 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# /opt/conda/lib/python3.8/site-packages/smdebug-1.0.13b20220304-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /opt/conda/lib/python3.8/site-packages/smdebug-1.0.13b20220304-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [2022-05-12 15:49:56.092 8aee3ff2d8c5:70200 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.299814
# Train Epoch: 1 [640/60000 (1%)]	Loss: 1.692979
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 0.900178
# ...

# %%
# Peak of Volatile GPU-Util: 13%
